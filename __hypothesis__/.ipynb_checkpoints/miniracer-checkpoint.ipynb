# %%
import os
import sys

# %%
from py_mini_racer import py_mini_racer as mr

# %%
def babel_transform(es_string):
    """ Transform the provided string using babel.transform """

    path_to_babel = os.path.join('/home/wyn/dev/PyMiniRacer', 'tests',
                                 'fixtures', 'babel.js')

    es6 = '[1,2,3].map(n => n + 1);'

    babel_source = open(path_to_babel, "r").read()

    # Initializes PyMiniRacer
    ctx = mr.MiniRacer()

    # Parse babel
    ctx.eval("""var self = this; %s """ % babel_source)

    # Transform stuff :)
    val = "babel.transform(`%s`)['code']" % es_string
    res = ctx.eval(val)
    return res

# %%
ctx = mr.MiniRacer()

# %%
cd ~/dev/reason/muuto/re-tree/src
# Out:
# /home/wyn/dev/reason/muuto/re-tree/src

# %%
ls
# Out:
# Graph.bs.js  graphs/         Identity.re   IDTree.re   Path.re  trees/
# Graph.re     Identity.bs.js  IDTree.bs.js  Path.bs.js  paths/

# %%
def evalJsBabel(ctx, js):
    js = babel_transform(js)
    print(js)
    return ctx.eval(js)

# %%
def evalJs(ctx, js):
    print(js)
    return ctx.eval(js)

# %%
def evalJsFile(ctx, fname):
    with open(fname) as f:
        return evalJs(ctx, f.read())

# %%
ctx.heap_stats()
# Out:
# {'total_physical_size': 885712,
#  'total_heap_size_executable': 1048576,
#  'total_heap_size': 3420160,
#  'used_heap_size': 800720,
#  'heap_size_limit': 1526909922}

# %%
evalJsFile(ctx, "./Path.bs.js")
# Out:
# // Generated by BUCKLESCRIPT, PLEASE EDIT WITH CARE
#
# //import * as Path_immutable$KaroshibeeReTree from "./paths/Path_immutable.bs.js";
# import {empty, size, fromList} from "./paths/Path_immutable.bs.js";
#
# var T = {
#   empty,
#   size,
#   fromList
#
#   // empty: Path_immutable$KaroshibeeReTree.empty,
#   // size: Path_immutable$KaroshibeeReTree.size,
#   // fromList: Path_immutable$KaroshibeeReTree.fromList,
#   // Frompathtorootlist: Path_immutable$KaroshibeeReTree.fromPathToRootList,
#   // fromRootToPathList: Path_immutable$KaroshibeeReTree.fromRootToPathList,
#   // moveUp: Path_immutable$KaroshibeeReTree.moveUp,
#   // moveDown: Path_immutable$KaroshibeeReTree.moveDown,
#   // parent: Path_immutable$KaroshibeeReTree.parent,
#   // root: Path_immutable$KaroshibeeReTree.root,
#   // pathToRoot: Path_immutable$KaroshibeeReTree.pathToRoot,
#   // pathFromRoot: Path_immutable$KaroshibeeReTree.pathFromRoot,
#   // eq: Path_immutable$KaroshibeeReTree.eq,
#   // append: Path_immutable$KaroshibeeReTree.append,
#   // toString: Path_immutable$KaroshibeeReTree.toString,
#   // removeElement: Path_immutable$KaroshibeeReTree.removeElement,
#   // concat: Path_immutable$KaroshibeeReTree.concat
# };
#
# var PID = /* alias */0;
#
# export {
#   PID ,
#   T ,
#
# }
# /* Path_immutable-KaroshibeeReTree Not a pure module */
# ---------------------------------------------------------------------------
# JSParseException                          Traceback (most recent call last)
# <ipython-input-23-012cbebc20ce> in <module>
# ----> 1 evalJsFile(ctx, "./Path.bs.js")
#
# <ipython-input-21-edd94a0d579a> in evalJsFile(ctx, fname)
#       1 def evalJsFile(ctx, fname):
#       2     with open(fname) as f:
# ----> 3         return evalJs(ctx, f.read())
#
# <ipython-input-20-5663c2857021> in evalJs(ctx, js)
#       1 def evalJs(ctx, js):
#       2     print(js)
# ----> 3     return ctx.eval(js)
#
# ~/.virtualenvs/re-tree/lib/python3.8/site-packages/py_mini_racer/py_mini_racer.py in eval(self, js_str, timeout, max_memory)
#     162             if bool(res) is False:
#     163                 raise JSConversionException()
# --> 164             python_value = res.contents.to_python()
#     165             return python_value
#     166         finally:
#
# ~/.virtualenvs/re-tree/lib/python3.8/site-packages/py_mini_racer/py_mini_racer.py in to_python(self)
#     294         elif self.type == PythonTypes.parse_exception:
#     295             msg = ctypes.c_char_p(self.value).value
# --> 296             raise JSParseException(msg)
#     297         elif self.type == PythonTypes.execute_exception:
#     298             msg = ctypes.c_char_p(self.value).value
#
# JSParseException: b'SyntaxError: Unexpected token {'

# %%
evalJsBabel(ctx, 'import m from "./Path.bs.js"')
# Out:
# "use strict";
#
# var _interopRequire = function (obj) { return obj && obj.__esModule ? obj["default"] : obj; };
#
# var m = _interopRequire(require("./Path.bs.js"));
# ---------------------------------------------------------------------------
# JSEvalException                           Traceback (most recent call last)
# <ipython-input-16-d12789762e89> in <module>
# ----> 1 evalJsBabel(ctx, 'import m from "./Path.bs.js"')
#
# <ipython-input-7-50be248155eb> in evalJsBabel(ctx, js)
#       2     js = babel_transform(js)
#       3     print(js)
# ----> 4     return ctx.eval(js)
#
# ~/.virtualenvs/re-tree/lib/python3.8/site-packages/py_mini_racer/py_mini_racer.py in eval(self, js_str, timeout, max_memory)
#     162             if bool(res) is False:
#     163                 raise JSConversionException()
# --> 164             python_value = res.contents.to_python()
#     165             return python_value
#     166         finally:
#
# ~/.virtualenvs/re-tree/lib/python3.8/site-packages/py_mini_racer/py_mini_racer.py in to_python(self)
#     297         elif self.type == PythonTypes.execute_exception:
#     298             msg = ctypes.c_char_p(self.value).value
# --> 299             raise JSEvalException(msg.decode('utf-8', errors='replace'))
#     300         elif self.type == PythonTypes.oom_exception:
#     301             msg = ctypes.c_char_p(self.value).value
#
# JSEvalException: ReferenceError: require is not defined
# ReferenceError: require is not defined
#     at <anonymous>:5:9

# %%
ctx

# %%
ctx.heap_stats()

# %%
ctx.
